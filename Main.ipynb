# %%
# !pip install cmake dlib face_recognition numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cmake in /home/anjalirana/.local/lib/python3.8/site-packages (3.24.3)
# Requirement already satisfied: dlib in /home/anjalirana/.local/lib/python3.8/site-packages (19.24.0)
# Requirement already satisfied: face_recognition in /home/anjalirana/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: numpy in /home/anjalirana/.local/lib/python3.8/site-packages (1.23.1)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from face_recognition) (7.0.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /home/anjalirana/.local/lib/python3.8/site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in /usr/lib/python3/dist-packages (from face_recognition) (7.0)

# %% [markdown]
# # Libraries

# %%
import cv2
#import numpy as np
import face_recognition
import os
from datetime import datetime

# %% [markdown]
# # Path for test images

# %%
path = 'AttendanceImages'
images = []
classNames = []
myList = os.listdir(path)
print(myList)
# Out:
# ['mitali.jpg', 'nirbhay.jpeg', 'Thakur.jpeg', 'amol.jpg', 'ridhima.jpg', 'Anjali.jpeg']

# %% [markdown]
# # Extracting names from the List

# %%
for cl in myList:
    curImg = cv2.imread(f'{path}/{cl}')
    images.append(curImg)
    classNames.append(os.path.splitext(cl)[0])
print(classNames)
# Out:
# ['mitali', 'nirbhay', 'Thakur', 'amol', 'ridhima', 'Anjali']

# %% [markdown]
# # Converting the Images into Encodings

# %%
def findEncodings(images):
    encodeList = []
    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encode = face_recognition.face_encodings(img)[0]
        encodeList.append(encode)
    return encodeList

# %% [markdown]
# # Marking Attendance

# %%
def markAttendance(name):
    with open('Attendance.csv','r+') as f:
        myDataList = f.readlines()
        nameList = []
        for line in myDataList:
            entry = line.split(',')
            nameList.append(entry[0])
        if name not in nameList:
            now = datetime.now()
            current_time= now.strftime('%H:%M:%S')
            # f.writelines(f'\n{name},{dtString}')
            date_today = now.strftime('%d/%m/%Y')
            f.writelines(f'{name},{current_time},{date_today}\n')
        

encodeListKnown = findEncodings(images)
print('Encoding Complete')
# Out:
# Encoding Complete

# %% [markdown]
# # Camera  Access and Capturing the Face

# %%
cap = cv2.VideoCapture(-1)
 
while True:
    success, img = cap.read()
    imgS = cv2.resize(img,(0,0),None,0.25,0.25)
    imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)
 
    facesCurFrame = face_recognition.face_locations(imgS)
    encodesCurFrame = face_recognition.face_encodings(imgS,facesCurFrame)
 
    for encodeFace,faceLoc in zip(encodesCurFrame,facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown,encodeFace)
        faceDis = face_recognition.face_distance(encodeListKnown,encodeFace)
        print(faceDis)
        matchIndex = np.argmin(faceDis)
 
    if matches[matchIndex]:
        name = classNames[matchIndex].upper()
        print(name)
        y1,x2,y2,x1 = faceLoc
        y1, x2, y2, x1 = y1*4,x2*4,y2*4,x1*4
        cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)
        cv2.rectangle(img,(x1,y2-35),(x2,y2),(0,255,0),cv2.FILLED)
        cv2.putText(img,name,(x1+6,y2-6),cv2.FONT_HERSHEY_COMPLEX,1,(255,255,255),2)
        markAttendance(name)
 
    cv2.imshow('Webcam',img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.69799922 0.71949345 0.76412915 0.78976408 0.68646095 0.53958242]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.63044975 0.63898373 0.71689255 0.79827483 0.61920757 0.53174412]
# ANJALI
# ANJALI
# [0.69082118 0.69984676 0.762655   0.79129776 0.68368174 0.49740294]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.63965534 0.7097564  0.74050875 0.75260564 0.65707976 0.51708211]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.68970396 0.71049824 0.75946219 0.78302799 0.68368006 0.52099933]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.66705062 0.6953732  0.73263657 0.73336119 0.68133138 0.52447016]
# ANJALI
# ANJALI
# ANJALI
# [0.61365462 0.72923033 0.79837749 0.76777227 0.64309705 0.4836443 ]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# [0.64490441 0.73224295 0.77842226 0.83633153 0.6332045  0.5446027 ]
# ANJALI
# ANJALI
# ANJALI
# ANJALI
# ANJALI
